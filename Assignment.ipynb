# %% [markdown]
# #About Dataset
# salaries dataset generally provides information about the employees of an organization in relation to their compensation. It typically includes details such as how much each employee is paid (their salary), their job titles, the departments they work in, and possibly additional information like their level of experience, education, and employment history within the organization.

# %% [markdown]
# # About Features
#
# 1. **Employee ID**: A unique identifier for each employee. Usually a numeric or alphanumeric code.
#
# 2. **Name**: The full name of the employee. This might be split into first and last names in some datasets.
#
# 3. **Department**: The department or division within the organization where the employee works.
#
# 4. **Job Title**: The official title or position held by the employee in the organization.
#
# 5. **Salary**: The amount of money the employee earns. This could be represented as an annual salary, hourly wage, or monthly pay.
#
# 6. **Hire Date**: The date when the employee started working at the organization. Useful for calculating tenure or experience.
#
# 7. **Gender**: The gender of the employee. This might be included in some datasets for diversity and equality analysis.
#
# 8. **Years of Experience**: The total number of years the employee has worked in their field or profession.
#
# 9. **Education Level**: The highest level of education attained by the employee, such as a high school diploma, bachelor's degree, etc.
#
# 10. **Performance Rating**: If available, this could be a measure of the employee's performance in their role, often based on annual review scores.
#
# 11. **Location**: The geographical location or office where the employee works, if the organization has multiple locations.

# %% [markdown]
# # Tasks
#
# 1. **Basic Data Exploration**: Identify the number of rows and columns in the dataset, determine the data types of each column, and check for missing values in each column.
#
# 2. **Descriptive Statistics**: Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation.
#
# 3. **Data Cleaning**: Handle missing data by suitable method with explain why you use it.
#
# 4. **Basic Data Visualization**: Create histograms or bar charts to visualize the distribution of salaries, and use pie charts to represent the proportion of employees in different departments.
#
# 5. **Grouped Analysis**: Group the data by one or more columns and calculate summary statistics for each group, and compare the average salaries across different groups.
#
# 6. **Simple Correlation Analysis**: Identify any correlation between salary and another numerical column, and plot a scatter plot to visualize the relationship.
#
# 8. **Summary of Insights**: Write a brief report summarizing the findings and insights from the analyses.

# %%
import pandas as pd
import numpy as np
import statistics
import matplotlib.pyplot as plt

# Load your dataset
df = pd.read_csv('SalariesX.csv')
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency
# 0  2011    NaN  San Francisco
# ...

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency'],
#       dtype='object')

# %%
#Q1:Basic Data Exploration
print("number of rows is:{} and the number of columns is:{}".format(df.shape[0],df.shape[1]))
print("determine the data types of each column")
df.info()
print("check for missing values in each column.")
df.isnull().sum()
# Out:
# number of rows is:148654 and the number of columns is:12
# determine the data types of each column
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
# dtypes: float64(7), int64(2), object(3)
# memory usage: 13.6+ MB
# ...

# %%
#Q2:
print('Calculate basic statistics for all the Data')
df.describe()
# Out:
# Calculate basic statistics for all the Data
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448841    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
print('Calculate basic statistics for TotalPay ')
df['TotalPay'].describe()
# Out:
# Calculate basic statistics for TotalPay
# count    148654.000000
# mean      74768.321972
# std       50517.005274
# min        -618.130000
# 25%       36168.995000
# 50%       71426.610000
# 75%      105839.135000
# max      567595.430000
# Name: TotalPay, dtype: float64

# %%
salary_range = np.max(df['TotalPay']) - np.min(df['TotalPay'])
median_salary = np.median(df['TotalPay'])
mode = statistics.mode(df['TotalPay'])

print("Median Salary:", median_salary)
print("Mode Salary:", mode)
print("Salary Range:", salary_range)
# Out:
# Median Salary: 71426.60999999999
# Mode Salary: 0.0
# Salary Range: 568213.56

# %%
#Q3:
del df['Notes']
#The column Notes have 148654 null value "all the value in this column are null"so i will delete this cloumn

# %%
df.dropna(subset=['BasePay'], inplace=True)
#BasePay have a 609 null value and when someone has no salary it means he is not defined so I will delete all this row

# %%
df['OvertimePay'].fillna(0, inplace=True) 
#We have 4 missing values so I will fill them with 0 to avoid change in BasePay
df['OtherPay'].fillna(0, inplace=True)
#We have 4 missing values so I will fill them with 0 to avoid change in BasePay
df['Benefits'].fillna(0, inplace=True)
#We have  missing values so I will fill them with 0 to avoid change in BasePay
df.isnull().sum()
# Out:
# Id                  0
# EmployeeName        0
# JobTitle            0
# BasePay             0
# OvertimePay         0
# OtherPay            0
# Benefits            0
# TotalPay            0
# TotalPayBenefits    0
# Year                0
# Agency              0
# dtype: int64

# %%
#Q4:
plt.hist(df['TotalPayBenefits'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel('Salary')
plt.ylabel('Frequency')
plt.title('Salary Distribution')
plt.show()

# %%
# Create bar chart for department distribution
#if we want to see the histogram for all the values wich it 2154 rows it will give us a distorted drawing because of the name of department 
department_counts = df['JobTitle'].value_counts()
plt.bar(department_counts.index, department_counts.values, color='lightgreen')
plt.xlabel('JobTitle')
plt.ylabel('Number of Employees')
plt.title('Employee Distribution by Department')
plt.show()
#if we take just the first 10 value we can see the deferns
department_counts2=department_counts.head(10)
plt.bar(department_counts2.index, department_counts2.values, color='lightgreen')
plt.xlabel('JobTitle')
plt.ylabel('Number of Employees')
plt.title('Employee Distribution by Department')
plt.xticks(rotation=45)
plt.show()

# %%
# Create pie chart for proportion of employees in different departments
plt.pie(department_counts, labels=department_counts.index, autopct='%1.1f%%', startangle=140, colors=['gold', 'lightcoral', 'lightskyblue', 'lightgreen'])
plt.axis('equal')
plt.title('Proportion of Employees in Different Departments')
plt.show()
################################
plt.pie(department_counts2, labels=department_counts2.index, autopct='%1.1f%%', startangle=140, colors=['gold', 'lightcoral', 'lightskyblue', 'lightgreen'])
plt.axis('equal')
plt.title('Proportion of Employees in Different Departments')
plt.show()

# %%
#Q5:
# the average salary for each group
grouped_data = df.groupby(['EmployeeName','JobTitle','TotalPay'])
summary_stats = grouped_data['TotalPay'].mean()
print(summary_stats)
# the average salary for each group
average_salaries = summary_stats.groupby('JobTitle').mean()
print(average_salaries)
# Out:
# EmployeeName           JobTitle                   TotalPay
# A BERNARD FATOOH       SHERIFF'S PROPERTY KEEPER  20039.91    20039.91
# A Bernard  Fatooh      Sheriff's Property Keeper  23923.62    23923.62
# A Bernard Fatooh       Sheriff's Property Keeper  18500.19    18500.19
#                                                   24061.35    24061.35
# A ELIZABETH MARCHASIN  PRINCIPAL CLERK            26282.86    26282.86
#                                                                 ...
# Zuna T Luu             Custodian                  56087.91    56087.91
#                                                   56155.44    56155.44
# Zuri  Jones            Deputy Probation Officer   71986.90    71986.90
# Zuri Jones             Deputy Probation Officer   66667.54    66667.54
#                                                   86588.52    86588.52
# Name: TotalPay, Length: 148022, dtype: float64
# JobTitle
# ACCOUNT CLERK                                     44035.664337
# ...

# %%
#Q6:
correlation = df['Year'].corr(df['TotalPay'])

# Plot a scatter plot to visualize the relationship
plt.scatter(df['Year'], df['TotalPay'])
plt.title('Year vs TotalPay')
plt.xlabel('Year')
plt.ylabel('TotalPay')
plt.show()

print("Correlation between Year and TotalPay:", correlation)
# Out:
# Correlation between Year and TotalPay: 0.03473284255489929

# %% [markdown]
# Q7:
# About Dataset salaries dataset generally provides information about the employees of an organization in relation to their compensation. It typically includes details such as how much each employee is paid (their salary), their job titles, the departments they work in, and possibly additional information like their level of experience, education, and employment history within the organization.
#
# first we import the Libraries pandas,numpy,statistics,matplotlib to help us in the code
# we read the data with: pd.read_csv('SalariesX.csv') and print the first 5 rows to see the values.
#
# to solve Q1: we use: df.shape that return the number of rows and columns in the dataset and we formated to make it easy to read like this: number of rows is:148654 and the number of columns is:12 .
#
# to determine the data types of each column we use: df.info() that return Dtype  for each column .
# and we check for missing values in each column by using: df.isnull().sum()
#
# and we found that:
#
# BasePay has 609 null value.
#
# OvertimePay and OtherPay have 4 nul value.
#
# Benefits has 36163 null value.
#
# Notes has 148654 null value.
#
# we Handle missing data in Q3:
# we Delete the column Notes because all the value in this column are null we use: del df['Notes'] to delete it.
#
# with BasePay we delete the rows that have null value with: df.dropna(subset=['BasePay'], inplace=True)
#
# OvertimePay, OtherPay and Benefits we fill them with 0 to avoid change in BasePay with: df['col_name'].fillna(0, inplace=True)
#
#
# Q2:we want to Calculate basic statistics mean, median, mode, minimum, and maximum salary, determine the range of salaries, and find the standard deviation,
# df['TotalPay'].describe() return mean ,minimum ,maximum and the standard deviation"std" :
#
# mean      74768.321972
#
# std       50517.005274
#
# min        -618.130000
#
# max      567595.430000
#
# then we use :
#
# salary_range = np.max(df['TotalPay']) - np.min(df['TotalPay'])
#
# median_salary = np.median(df['TotalPay'])
#
# mode = statistics.mode(df['TotalPay'])
#
# to Calculate the rest:
#
# Median Salary: 71426.60999999999
#
# Mode Salary: 0.0
#
# Salary Range: 568213.56
#
# Q4:we want to Create histograms or bar charts to visualize the distribution of salaries so we use:plt.hist(df['TotalPayBenefits'], bins=10, color='skyblue', edgecolor='black')
#
# use pie charts to represent the proportion of employees in different departments
# we creat the series that contain  :
# department_counts = df['JobTitle'].value_counts()
#
# then we use this instructions to plot it:
# plt.pie(department_counts, labels=department_counts.index, autopct='%1.1f%%', startangle=140,
# colors=['gold', 'lightcoral','lightskyblue', 'lightgreen'])
#
# plt.axis('equal')
#
# plt.title('Proportion of Employees in Different Departments')
#
# plt.show()
#
# Q5:we want to Group the data by one or more columns so we grouped 'EmployeeName','JobTitle','TotalPay'
# and calculate summary statistics for each group, and compare the average salaries across different groups by using:
# summary_stats = grouped_data['TotalPay'].mean()
#
# average_salaries = summary_stats.groupby('JobTitle').mean()
#
# Q6: Identify any correlation between salary and another numerical column so we use:
# correlation = df['Year'].corr(df['TotalPay'])
#
# and plot a scatter plot to visualize the relationship: in the histograms We observed salary payments in each year.
